# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/Vic/Desktop/Data Scienece/Datasets-20231016/Dataset_Melbourne.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
total_missing = df.isnull().sum().sum()
print(total_missing)
# Out:
# 100975

# %%
df_cleaned = df.dropna(subset=['Price'])
#  Here I dropped rows with missing values, because imputing values in the target variable
# can introduce significant bias or inaccuracies -- explanation in word sheet

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27247 entries, 1 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27247 non-null  object
#  1   Address        27247 non-null  object
#  2   Rooms          27247 non-null  int64
#  3   Type           27247 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         27247 non-null  object
#  6   SellerG        27247 non-null  object
#  7   Date           27247 non-null  object
#  8   Distance       27246 non-null  float64
#  9   Postcode       27246 non-null  float64
#  10  Bedroom2       20806 non-null  float64
#  11  Bathroom       20800 non-null  float64
#  12  Car            20423 non-null  float64
#  13  Landsize       17982 non-null  float64
#  14  BuildingArea   10656 non-null  float64
#  15  YearBuilt      12084 non-null  float64
#  16  CouncilArea    27244 non-null  object
# ...

# %%
y = df_cleaned['Price']
#Target variable y is what we are trying to predict or explain. y = target variable
#defined it by extracting it from the DataFrame

# %%
X = df_cleaned.drop(columns=['Price'])
#We drop column price -- X = Features or independet variables

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Here we don't use the stratify parameter, because the target variable is numerical/continious

# %%
print("New length:", len(df_cleaned), "rows")
print(df_cleaned.isnull().sum())
# Out:
# New length: 27247 rows
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          6441
# Bathroom          6447
# Car               6824
# Landsize          9265
# BuildingArea     16591
# YearBuilt        15163
# CouncilArea          3
# Lattitude         6254
# Longtitude        6254
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
missing_values2 = X_train.isnull().sum()
print(missing_values2[missing_values2 > 0])
# Out:
# Distance             1
# Postcode             1
# Bedroom2          4519
# Bathroom          4525
# Car               4798
# Landsize          6511
# BuildingArea     11600
# YearBuilt        10591
# CouncilArea          3
# Lattitude         4375
# Longtitude        4375
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
print(X_train.dtypes)
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
# Changes output of the transformers to Pandas
from sklearn import set_config
set_config(transform_output="pandas")

# import the imputing function
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
print("New length:", len(X_train), "rows")
print(X_train.isnull().sum())
# Out:
# New length: 19072 rows
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4519
# Bathroom          4525
# Car               4798
# Landsize          6511
# BuildingArea     11600
# YearBuilt        10591
# CouncilArea          3
# Lattitude         4375
# Longtitude        4375
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# define imputer and strategy
numeric_imputer = SimpleImputer(strategy="median")
categorical_imputer = SimpleImputer(strategy='most_frequent')
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
#OneHotEncoder to change categoric columns into numeric
#SimpleImputer to fill missing values from numerical columns

# %%
print("New length:", len(X_train), "rows")
print(X_train.isnull().sum())
# Out:
# New length: 19072 rows
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4519
# Bathroom          4525
# Car               4798
# Landsize          6511
# BuildingArea     11600
# YearBuilt        10591
# CouncilArea          3
# Lattitude         4375
# Longtitude        4375
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# Here we define which columns are numerical and which categorical
numeric_features = ['Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount']
categorical_features = ['CouncilArea', 'Regionname', 'Suburb', 'Type', 'Method', 'SellerG']

# %%
#Create a ColumnTransformer
ct = ColumnTransformer(
    transformers=[
        ('num', numeric_imputer, numeric_features),
        ('cat', ohe, categorical_features)
        ])

# %%
X_train_processed = ct.fit_transform(X_train)
X_test_processed = ct.transform(X_test)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
dtr_pipeline = Pipeline([
    ('preprocesser', ct),
    ('regressor', DecisionTreeRegressor(random_state=42))
])

# %%
dtr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['Distance', 'Postcode',
#                                                    'Bedroom2', 'Bathroom',
#                                                    'Car', 'Landsize',
#                                                    'BuildingArea', 'YearBuilt',
#                                                    'Lattitude', 'Longtitude',
#                                                    'Propertycount']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['CouncilArea', 'Regionname',
# ...

# %%
y_pred_dtr= dtr_pipeline.predict(X_test)

r2 = r2_score(y_test, y_pred_dtr)
mae = mean_absolute_error(y_test, y_pred_dtr)
rmse = mean_squared_error(y_test, y_pred_dtr, squared=False)
mse = mean_squared_error(y_test, y_pred_dtr, squared=True)
print("R-squared:", r2)
print("MAE:", mae)
print("RMSE:", rmse)
print("MSE:", mse)
# Out:
# R-squared: 0.5847059555556753
# MAE: 238263.45971584652
# RMSE: 413026.97368122055
# MSE: 170591280988.26767

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=42)
rf.fit(X_train_processed, y_train)
y_pred_rf = rf.predict(X_test_processed)

print("RF_R-squared:", r2_score(y_test, y_pred_rf))
print("RF_MAE:", mean_absolute_error(y_test, y_pred_rf))
print("RF_RMSE:", mean_squared_error(y_test, y_pred_rf, squared=False))
print("RF_MSE:", mean_squared_error(y_test, y_pred_rf, squared=True))
# Out:
# RF_R-squared: 0.7276768577994891
# RF_MAE: 188119.6168644231
# RF_RMSE: 334458.9626223777
# RF_MSE: 111862797678.43703

# %%
from sklearn.linear_model import LinearRegression

# %%
#Create a pipeline
lr_pipeline = Pipeline([
    ('preprocesser', ct),
    ('regressor', LinearRegression())
])
#Train the pipeline
lr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['Distance', 'Postcode',
#                                                    'Bedroom2', 'Bathroom',
#                                                    'Car', 'Landsize',
#                                                    'BuildingArea', 'YearBuilt',
#                                                    'Lattitude', 'Longtitude',
#                                                    'Propertycount']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['CouncilArea', 'Regionname',
# ...

# %%
# Predict on the Test set
y_pred_lr = lr_pipeline.predict(X_test)

#Calculate the MAE and RSME
mae_lr = mean_absolute_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))

print(f"linear Regression MAE {mae_lr}")
print(f"linear Regression RMSE {rmse_lr}")
# Out:
# linear Regression MAE 249201.15307401167
# linear Regression RMSE 601664.3422989184

# %%
from sklearn.model_selection import GridSearchCV

# Define grid
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# RandomForestRegressor
rf = RandomForestRegressor(random_state=42)

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the GridSearchCV
grid_search.fit(X_train_processed, y_train)

# Print 
print("Best Parameters:", grid_search.best_params_)

# Get the best model
best_rf = grid_search.best_estimator_

# Predict
y_pred = best_rf.predict(X_test_processed)

# Evaluate model performance
print("R-squared:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred, squared=False))
print("MSE:", mean_squared_error(y_test, y_pred, squared=True))
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Vic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Vic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\__init__.py", line 83, in <module>
# ...
